# %% [markdown]
# ## Part 1: Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras import layers

#  Import and read the attrition data
attrition_df = pd.read_csv(
    "https://static.bc-edx.com/ai/ail-v-1-0/m19/lms/datasets/attrition.csv"
)
attrition_df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  HourlyRate  \
# 0          2  Life Sciences                        2          94
# 1          1  Life Sciences                        3          61
# 2          2          Other                        4          92
# 3          4  Life Sciences                        4          56
# 4          1        Medical                        1          40
#
#    JobInvolvement  ...  PerformanceRating RelationshipSatisfaction  \
# ...

# %%
# Determine the number of unique values in each column
attrition_df.nunique()
# Out:
# Age                         43
# Attrition                    2
# BusinessTravel               3
# Department                   3
# DistanceFromHome            29
# Education                    5
# EducationField               6
# EnvironmentSatisfaction      4
# HourlyRate                  71
# JobInvolvement               4
# JobLevel                     5
# JobRole                      9
# JobSatisfaction              4
# MaritalStatus                3
# NumCompaniesWorked          10
# OverTime                     2
# PercentSalaryHike           15
# PerformanceRating            2
# RelationshipSatisfaction     4
# StockOptionLevel             4
# TotalWorkingYears           40
# TrainingTimesLastYear        7
# WorkLifeBalance              4
# YearsAtCompany              37
# YearsInCurrentRole          19
# YearsSinceLastPromotion     16
# YearsWithCurrManager        18
# dtype: int64

# %%
# Create y_df with the Attrition and Department columns
y_df = attrition_df[["Attrition", "Department"]]
y_df.head()
# Out:
#   Attrition              Department
# 0       Yes                   Sales
# 1        No  Research & Development
# 2       Yes  Research & Development
# 3        No  Research & Development
# 4        No  Research & Development

# %%
# Create a list of at least 10 column names to use as X data
X = attrition_df[
    [
        "Age",
        "DistanceFromHome",
        "Education",
        "JobSatisfaction",
        "NumCompaniesWorked",
        "OverTime",
        "StockOptionLevel",
        "TotalWorkingYears",
        "WorkLifeBalance",
        "YearsAtCompany",
    ]
]

# Create X_df using your selected columns
X_df = X

# Show the data types for X_df
X.dtypes.to_frame()
# Out:
#                          0
# Age                  int64
# DistanceFromHome     int64
# Education            int64
# JobSatisfaction      int64
# NumCompaniesWorked   int64
# OverTime            object
# StockOptionLevel     int64
# TotalWorkingYears    int64
# WorkLifeBalance      int64
# YearsAtCompany       int64

# %%
X_df
# Out:
#       Age  DistanceFromHome  Education  JobSatisfaction  NumCompaniesWorked  \
# 0      41                 1          2                4                   8
# 1      49                 8          1                2                   1
# 2      37                 2          2                3                   6
# 3      33                 3          4                3                   1
# 4      27                 2          1                2                   9
# ...   ...               ...        ...              ...                 ...
# 1465   36                23          2                4                   4
# 1466   39                 6          1                1                   4
# 1467   27                 4          3                2                   1
# 1468   49                 2          3                2                   2
# 1469   34                 8          3                3                   2
#
# ...

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_df, y_df, random_state=42)
print(X_train['OverTime'].value_counts())
X_train.head()
# Out:
# OverTime
# No     780
# Yes    322
# Name: count, dtype: int64
#       Age  DistanceFromHome  Education  JobSatisfaction  NumCompaniesWorked  \
# 1343   29                 7          3                1                   3
# 1121   36                 1          4                3                   6
# 1048   34                 3          3                1                   3
# 1393   27                 9          3                4                   1
# 527    32                10          3                4                   1
#
#      OverTime  StockOptionLevel  TotalWorkingYears  WorkLifeBalance  \
# 1343       No                 0                 11                3
# 1121       No                 0                 15                3
# 1048       No                 0                 15                3
# 1393       No                 0                  7                3
# 527        No                 0                 10                2
#
#       YearsAtCompany
# ...

# %%
# Convert your X data to numeric data types however you see fit
# Add new code cells as necessary
from sklearn.preprocessing import OneHotEncoder

ot_encoder = OneHotEncoder(sparse_output=False, drop='first')

X_train_ot_encoded = ot_encoder.fit_transform(X_train[['OverTime']])
X_test_ot_encoded = ot_encoder.transform(X_test[['OverTime']])


ot_features = ot_encoder.get_feature_names_out(['OverTime'])

X_train_ot_df = pd.DataFrame(X_train_ot_encoded, columns=ot_features, index=X_train.index)
X_test_ot_df = pd.DataFrame(X_test_ot_encoded, columns=ot_features, index=X_test.index)

X_train = X_train.drop(columns=['OverTime'])
X_test = X_test.drop(columns=['OverTime'])

X_train = pd.concat([X_train, X_train_ot_df], axis=1)
X_test = pd.concat([X_test, X_test_ot_df], axis=1)

X_train.head()
# Out:
#       Age  DistanceFromHome  Education  JobSatisfaction  NumCompaniesWorked  \
# 1343   29                 7          3                1                   3
# 1121   36                 1          4                3                   6
# 1048   34                 3          3                1                   3
# 1393   27                 9          3                4                   1
# 527    32                10          3                4                   1
#
#       StockOptionLevel  TotalWorkingYears  WorkLifeBalance  YearsAtCompany  \
# 1343                 0                 11                3               3
# 1121                 0                 15                3               1
# 1048                 0                 15                3              13
# 1393                 0                  7                3               7
# 527                  0                 10                2              10
#
#       OverTime_Yes
# 1343           0.0
# ...

# %%
# Create a StandardScaler
scaler = StandardScaler()

# Fit the StandardScaler to the training data
scaler.fit(X_train)
# Scale the training and testing data
X_train_scaled = pd.DataFrame(scaler.transform(X_train), columns=X_train.columns) 
X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns) 

X_train_scaled
# Out:
#            Age  DistanceFromHome  Education  JobSatisfaction  \
# 0    -0.852159         -0.285906   0.094018        -1.569331
# 1    -0.093088         -1.017204   1.053349         0.251093
# 2    -0.309965         -0.773438   0.094018        -1.569331
# 3    -1.069036         -0.042139   0.094018         1.161305
# 4    -0.526843          0.079744   0.094018         1.161305
# ...        ...               ...        ...              ...
# 1097 -0.201527          2.273640   0.094018         0.251093
# 1098  0.449105         -0.529672   0.094018        -0.659119
# 1099 -1.611229         -0.773438   1.053349         1.161305
# 1100 -0.852159          0.445393  -0.865313        -0.659119
# 1101  1.425053         -0.042139   0.094018         0.251093
#
#       NumCompaniesWorked  StockOptionLevel  TotalWorkingYears  \
# 0               0.138872         -0.949842          -0.014296
# 1               1.331364         -0.949842           0.498037
# ...

# %%
# Create a OneHotEncoder for the Department column
from sklearn.preprocessing import OneHotEncoder

dept_encoder = OneHotEncoder(sparse_output=False)

# Fit the encoder to the training data
dept_encoder.fit(y_train[["Department"]])

# Create two new variables by applying the encoder
# to the training and testing data
y_train_department_encoded = dept_encoder.transform(y_train[["Department"]])
y_test_department_encoded = dept_encoder.transform(y_test[["Department"]])

print(y_test_department_encoded.shape)
print(dept_encoder.categories_[0])
# Out:
# (368, 3)
# ['Human Resources' 'Research & Development' 'Sales']

# %%
# Create a OneHotEncoder for the Attrition column
attrition_encoder = OneHotEncoder(sparse_output=False)

# Fit the encoder to the training data
attrition_encoder.fit(y_train[["Attrition"]])

# Create two new variables by applying the encoder
# to the training and testing data
y_train_attrition_encoded = attrition_encoder.transform(y_train[["Attrition"]])
y_test_attrition_encoded = attrition_encoder.transform(y_test[["Attrition"]])

print(y_test_attrition_encoded.shape)
# Out:
# (368, 2)

# %% [markdown]
# ## Part 2: Create, Compile, and Train the Model

# %%
# Find the number of columns in the X training data.
print(X_train.shape[1]) # == 10
# Create the input layer
input_layer = layers.Input(shape=(X_train.shape[1], ))

# Create at least two shared layers
shared_layer1 = layers.Dense(32, activation="relu", name="shared_1")(input_layer)
shared_layer2 = layers.Dense(16, activation="relu", name="shared_2")(shared_layer1)
# Out:
# 10

# %%
# %% Create a branch for Department
# with a hidden layer and an output layer

# Create the hidden layer
department_hidden = layers.Dense(8, activation="relu")(shared_layer2)
# Create the output layer
department_output = layers.Dense(y_train_department_encoded.shape[1], activation="softmax", name="department_output")(department_hidden)
print(y_train_department_encoded.shape[1])

# y_train_department_encoded.shape[1] == 3
# Out:
# 3

# %%
# %% Create a branch for Attrition
# with a hidden layer and an output layer

# Create the hidden layer
attrition_hidden = layers.Dense(8, activation="relu")(shared_layer2)
# Create the output layer
attrition_output = layers.Dense(y_train_attrition_encoded.shape[1], activation="sigmoid", name="attrition_output")(attrition_hidden)
print(y_train_attrition_encoded.shape[1])

# y_train_attrition_encoded.shape[1] == 2
# Out:
# 2

# %%
# Create the model
model = Model(inputs=input_layer, outputs=[attrition_output, department_output])
# Compile the model
model.compile(
    optimizer="adam",
    loss={
        "attrition_output": "binary_crossentropy",
        "department_output": "categorical_crossentropy",
    },
    metrics={
        "attrition_output": "accuracy",
        "department_output": "accuracy"
    },
)
# Summarize the model
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 10)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_1 (Dense)    │ (None, 32)        │        352 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_2 (Dense)    │ (None, 16)        │        528 │ shared_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 8)         │        136 │ shared_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
# Train the model
model.fit(
    X_train_scaled,
    {
        "attrition_output": y_train_attrition_encoded,
        "department_output": y_train_department_encoded,
    },
    epochs=100,
    verbose=1,
)
# Out:
# Epoch 1/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 904us/step - attrition_output_accuracy: 0.3097 - attrition_output_loss: 0.7282 - department_output_accuracy: 0.2751 - department_output_loss: 1.1285 - loss: 1.8568
# Epoch 2/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - attrition_output_accuracy: 0.6488 - attrition_output_loss: 0.6715 - department_output_accuracy: 0.4611 - department_output_loss: 1.0506 - loss: 1.7220
# Epoch 3/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - attrition_output_accuracy: 0.8014 - attrition_output_loss: 0.6229 - department_output_accuracy: 0.5553 - department_output_loss: 0.9803 - loss: 1.6032
# Epoch 4/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step - attrition_output_accuracy: 0.8259 - attrition_output_loss: 0.5363 - department_output_accuracy: 0.6159 - department_output_loss: 0.8827 - loss: 1.4191
# Epoch 5/100
# ...

# %%
# Evaluate the model with the testing data
loss, attrition_loss, department_loss, attrition_accuracy, department_accuracy = model.evaluate(
    X_test_scaled,
    {
        "attrition_output": y_test_attrition_encoded,
        "department_output": y_test_department_encoded,
    },
    verbose=1,
)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - attrition_output_accuracy: 0.8575 - attrition_output_loss: 0.4758 - department_output_accuracy: 0.5927 - department_output_loss: 0.8920 - loss: 1.3672

# %%
# Print the accuracy for both department and attrition
print(f"Attrition predictions accuracy: {attrition_accuracy}")
print(f"Department predictions accuracy: {department_accuracy}")
# Out:
# Attrition predictions accuracy: 0.8614130616188049
# Department predictions accuracy: 0.592391312122345

# %% [markdown]
# # Summary
#
# In the provided space below, briefly answer the following questions.
#
# 1. Is accuracy the best metric to use on this data? Why or why not?
#
# 2. What activation functions did you choose for your output layers, and why?
#
# 3. Can you name a few ways that this model might be improved?

# %% [markdown]
# YOUR ANSWERS HERE
#
# 1. Accuracy may not be the best metric if the dataset is imbalanced (more "No" than "Yes" in Attrition). Other metrics (precision, recall, F1-score) are better for evaluating performance and account for class imbalance.
#
# 2.
# - Sigmoid for 'Attrition' because it is used for binary classification, outputting a probability between 0 and 1.
#
# - Softmax for 'Department' because it is used for multi-class classification, where probabilities of all classes sum to 1.
#
#
# 3. More data, Regularization, Class balancing, Early stopping, Hyperparam tuning
